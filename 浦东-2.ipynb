# %%
# -* coding: utf-8 *-
#author: wangshx6
#data: 2018-11-07
#descriptinon: 爬取链家深圳全部二手房的详细信息，并将爬取的数据存储到CSV文
 
import requests
from bs4 import BeautifulSoup
import pandas as pd
from fake_useragent import UserAgent

URL1="https://sh.lianjia.com/ershoufang/pudong/y4sf1l2l3a3a4p3p4p5/"
URL2="https://sh.lianjia.com/ershoufang/pudong/pg{}y4sf1l2l3a3a4p3p4p5/"
name="浦东-300~800w-20年-2、3室"
 
class LianjiaSpider(object):
 
    def __init__(self):
        self.headers = {"User-Agent": UserAgent().random}
        self.datas = list()
 
    def getMaxPage(self, url):
        response = requests.get(url, headers = self.headers)
        if response.status_code == 200:
            source = response.text
            soup = BeautifulSoup(source, "html.parser")
            pageData = soup.find("div", class_ = "page-box house-lst-page-box")["page-data"]
            # pageData = '{"totalPage":100,"curPage":1}'，通过eval()函数把字符串转换为字典
            maxPage = eval(pageData)["totalPage"]
            return  maxPage
        else:
            print("Fail status: {}".format(response.status_code))
            return None
 
 
    def parsePage(self, url):
        maxPage = self.getMaxPage(url)
        #  解析每个page，获取每个二手房的链接
        print(maxPage)
        for pageNum in range(1, maxPage+1 ):
            url = URL2.format(pageNum)
            print("当前正在爬取: {}".format(url))
            response = requests.get(url, headers = self.headers)
            soup = BeautifulSoup(response.text, "html.parser")
            links = soup.find_all("div", class_ = "info clear")
            for i in links:
                link = i.find("a")["href"]    #每个<info clear>标签有很多<a>,而我们只需要第一个，所以用find
                detail = self.parseDetail(link)
                self.datas.append(detail)
                print(pageNum+"already done")
 
        #  将所有爬取的二手房数据存储到csv文件中
        data = pd.DataFrame(self.datas)
        # columns字段：自定义列的顺序（DataFrame默认按列名的字典序排序）
        columns = ["小区", "户型", "楼层","面积", "价格", "单价", "朝向", "电梯", "位置", "地铁","装修情况","套内面积","使用年限","挂牌时间","房屋年限"]
        data.to_csv(".\浦东_2.csv", encoding='utf_8_sig', index=False, columns=columns)
 
 
    def parseDetail(self, url):
        response = requests.get(url, headers = self.headers)
        detail = {}
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            detail["价格"] = soup.find("span", class_ = "total").text
            detail["单价"] = soup.find("span", class_ = "unitPriceValue").text
            #detail["信息"] = soup.find("div", class_ = "houseInfo").text
            
            #detail["关注"] = soup.find("div", class_ = "starIcon").text
            #info = soup.find("span", class_ = "starIcon").find_all("div") # 基本信息
            #detail["关注"] = info
            detail["小区"] = soup.find("div", class_ = "communityName").find("a", class_ = "info").text
            detail["位置"] = soup.find("div", class_="areaName").find("span", class_="info").text
            detail["地铁"] = soup.find("div", class_="areaName").find("a", class_="supplement").text
            base = soup.find("div", class_ = "base").find_all("li") # 基本信息
            detail["户型"] = base[0].text[4:]
            detail["楼层"] = base[1].text[4:]
            detail["面积"] = base[2].text[4:]
            detail["套内面积"] = base[4].text[4:]
            detail["朝向"] = base[6].text[4:]
            detail["装修情况"] = base[8].text[4:]
            detail["电梯"] = base[10].text[4:]
            detail["使用年限"] = base[11].text[4:]
            trans = soup.find("div", class_ = "transaction").find_all("li") # 基本信息
            detail["挂牌时间"] = trans[0].text[4:]
            detail["房屋年限"] = trans[4].text[4:]
            
            return detail
        else:
            return None
 
if __name__ == "__main__":
    Lianjia = LianjiaSpider()
    Lianjia.parsePage(URL1)
# Out:
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg1y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg2y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg3y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg4y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg5y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg6y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg7y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg8y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg9y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg10y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg11y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg12y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg13y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg14y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg15y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg16y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg17y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg18y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg19y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg20y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg21y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg22y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg23y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg24y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg25y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg26y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg27y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg28y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg29y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg30y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg31y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg32y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg33y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg34y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg35y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg36y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg37y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg38y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg39y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg40y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg41y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg42y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg43y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg44y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg45y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg46y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg47y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg48y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg49y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg50y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg51y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg52y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg53y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg54y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg55y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg56y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg57y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg58y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg59y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg60y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg61y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg62y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg63y4sf1l2l3a3a4p3p4p5/
# 当前正在爬取: https://sh.lianjia.com/ershoufang/pudong/pg64y4sf1l2l3a3a4p3p4p5/

# %%
# Out:
# 2
